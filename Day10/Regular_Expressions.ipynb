# %%
import re
regex1="i*"
# regex2="si*"
S1="iacsd"
S2="sii"
S3="abc"

# %%
re.findall(regex1,S1)
# Out:
# ['i', '', '', '', '', '']

# %%
re.findall(regex1,S2)
# Out:
# ['', 'ii', '']

# %%
re.findall(regex1,S3)
# Out:
# ['', '', '', '']

# %%
re.findall(regex2,S1)#si*
# Out:
# ['s']

# %%
re.findall(regex2,S2)
# Out:
# ['sii']

# %%
re.findall(regex2,S3)
# Out:
# []

# %% [markdown]
# # {m,n} Example

# %%
regex="[0-9]{2,4}"
S1="456"
S2="9BN"
S3="67HJK890780"

# %%
re.findall(regex,S1)
# Out:
# ['456']

# %%
re.findall(regex,S2)
# Out:
# []

# %%
re.findall(regex,S3)
# Out:
# ['67', '8907', '80']

# %% [markdown]
# # Use Search

# %%
regex="[0-9]{2,4}"
S1="456"
S2="9BN"
S3="67HJK890780"

# %%
re.search(regex,S1)
# Out:
# <re.Match object; span=(0, 3), match='456'>

# %%
m = re.search(regex,S1)
m[0]
# Out:
# '456'

# %%
S1[0:3]
# Out:
# '456'

# %%
m.span()
# Out:
# (0, 3)

# %%
m = re.search(regex,S3)
m[0]
# Out:
# '67'

# %%
m.span()
# Out:
# (0, 2)
